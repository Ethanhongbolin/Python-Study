# %% [markdown]
# # 01 - Basic Syntax

# %%
count = 5
while count > 0:
    print(count)
    count -= 1 # update the count so the while loop can stop, without this line, it would continue to print("5") forever
print("Liftoff")
# Out:
# 5
# 4
# 3
# 2
# 1
# Liftoff

# %% [markdown]
# # 02 - Using a Flag Variable
# A flag is a boolean that controls when to stop
#
# expected output is:
#
# Found 9 at index 3

# %%
found = False
numbers = [4,7,2,9,1,5]
target = 9

# %% [markdown]
# # 03 - in class assignment
# input a string as a password
#
# and validate with a while loop
#
# if the validation is the same the same as the original created password
#
# print("login succesful")
#
# otherwise
#
# print("login fails \nplease try again lateer")

# %%
go = True
password = input("Please enter password: ")

password_check = input("please enter your original password: ")
tries = 1
while password != password_check:
    print("login failed, please try again later")
    password_check = input("please enter your original password: ")
    tries += 1
    if tries == 3:
        break

if tries == 3:
    print("wait 5 minuites")
else:
    print("successfull")
# Out:
# login failed, please try again later
# login failed, please try again later
# wait 5 minuites

# %%
go = True
password = input("Please enter password: ")

password_check = input("please enter your original password: ")
tries = 1
while password != password_check and tries != 3:
    print("login failed, please try again later")
    password_check = input("please enter your original password: ")
    tries += 1

if tries == 3:
    print("wait 5 minuites")
else:
    print("successfull")
